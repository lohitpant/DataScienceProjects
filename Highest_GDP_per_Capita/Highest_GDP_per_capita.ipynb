# %% [markdown]
# # Find and compare countries with Highest GDP per capita

# %% [markdown]
# Step 1: Importing necessary libraries and data set in .csv format

# %%
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv('nations.csv')
data.head()
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  1996         NaN          NaN     64291.0        10.9
# 1    AD   AND  Andorra  1994         NaN          NaN     62707.0        10.9
# 2    AD   AND  Andorra  2003         NaN          NaN     74783.0        10.3
# 3    AD   AND  Andorra  1990         NaN          NaN     54511.0        11.9
# 4    AD   AND  Andorra  2009         NaN          NaN     85474.0         9.9
#
#    neonat_mortal_rate                 region       income
# 0                 2.8  Europe & Central Asia  High income
# 1                 3.2  Europe & Central Asia  High income
# 2                 2.0  Europe & Central Asia  High income
# 3                 4.3  Europe & Central Asia  High income
# 4                 1.7  Europe & Central Asia  High income

# %% [markdown]
# Step 2: Filling N/A values with median values for 'gdp_percp' column

# %%
data['gdp_percap'].fillna(data['gdp_percap'].median(), inplace=True)
data.head(10)
# Out:
#   iso2c iso3c  country  year   gdp_percap  life_expect  population  \
# 0    AD   AND  Andorra  1996  6563.171063          NaN     64291.0
# 1    AD   AND  Andorra  1994  6563.171063          NaN     62707.0
# 2    AD   AND  Andorra  2003  6563.171063          NaN     74783.0
# 3    AD   AND  Andorra  1990  6563.171063          NaN     54511.0
# 4    AD   AND  Andorra  2009  6563.171063          NaN     85474.0
# 5    AD   AND  Andorra  2011  6563.171063          NaN     82326.0
# 6    AD   AND  Andorra  2004  6563.171063          NaN     78337.0
# 7    AD   AND  Andorra  2010  6563.171063          NaN     84419.0
# 8    AD   AND  Andorra  2001  6563.171063          NaN     67770.0
# 9    AD   AND  Andorra  2002  6563.171063          NaN     71046.0
#
#    birth_rate  neonat_mortal_rate                 region       income
# 0        10.9                 2.8  Europe & Central Asia  High income
# 1        10.9                 3.2  Europe & Central Asia  High income
# ...

# %% [markdown]
# Step 3: Grouping the data by 'country' column and finding mean of it for each country

# %%
avggdp_percap = data.groupby(['country']).mean()['gdp_percap']
avggdp_percap
# Out:
# country
# Afghanistan                  3875.455615
# Albania                      5641.509114
# Algeria                      9608.372262
# American Samoa               6563.171063
# Andorra                      6563.171063
# Angola                       4115.678146
# Antigua and Barbuda         16961.378101
# Argentina                    6563.171063
# Armenia                      3992.636430
# Aruba                        7741.247039
# Australia                   29909.325163
# Austria                     32440.578064
# Azerbaijan                   7916.242744
# Bahamas, The                20030.669610
# Bahrain                     35876.449331
# Bangladesh                   1655.148382
# Barbados                    12123.359699
# Belarus                      9118.246224
# Belgium                     30545.334583
# Belize                       6051.899126
# Benin                        1409.111949
# Bermuda                     40909.171044
# Bhutan                       3903.189133
# ...

# %% [markdown]
# Step 4: Sorting the data in Decreasing order as per 'gdp_percap' and printing top 5 countries

# %%
top_five=avggdp_percap.sort_values(ascending=False).head(5)
top_five
# Out:
# country
# United Arab Emirates    74738.442986
# Qatar                   70772.168796
# Brunei Darussalam       63116.905041
# Luxembourg              62343.738409
# Kuwait                  58301.181985
# Name: gdp_percap, dtype: float64

# %% [markdown]
# Step 5: We will save 'United Arab Emirates' country data in 'uae' variable aftr sorting it 'year' wise

# %%
uae=data[data['country']=='United Arab Emirates'].sort_values('year')
uae
# Out:
#    iso2c iso3c               country  year    gdp_percap  life_expect  \
# 36    AE   ARE  United Arab Emirates  1990  74017.300650    71.720146
# 25    AE   ARE  United Arab Emirates  1991  73036.996606    72.012293
# 28    AE   ARE  United Arab Emirates  1992  73154.277741    72.296415
# 26    AE   ARE  United Arab Emirates  1993  71959.877867    72.573024
# 29    AE   ARE  United Arab Emirates  1994  74683.888594    72.845585
# 44    AE   ARE  United Arab Emirates  1995  77467.244845    73.115073
# 32    AE   ARE  United Arab Emirates  1996  79480.467479    73.383927
# 37    AE   ARE  United Arab Emirates  1997  83165.263147    73.652659
# 39    AE   ARE  United Arab Emirates  1998  80040.216703    73.920220
# 35    AE   ARE  United Arab Emirates  1999  79262.386452    74.187171
# 34    AE   ARE  United Arab Emirates  2000  84974.894091    74.451537
# 27    AE   ARE  United Arab Emirates  2001  83533.555216    74.712878
# ...

# %% [markdown]
# Step 6: Now we will plot 'uae' data with 'year' on x axis and 'gdp_percap' on y axis with line plot.

# %%
axis= plt.plot(uae['year'], uae['gdp_percap'])
axis=set_xlabel='Year'
axis=set_ylabel='GDP Per Capita'

# %% [markdown]
# Step 7: To better understand we will bar plot 'uae'

# %%
uae.plot.bar(x='year', y='gdp_percap')

# %% [markdown]
# Step 8: We will plot Qatar(Second highest GDP per cap) data in bar plot by saving it in qt var

# %%
qt=data[data['country']=='Qatar'].sort_values('year')
qt.plot.bar(x='year',y='gdp_percap')

# %% [markdown]
# Step 9: Now we will compare highest gdp per cap country (uae) with second highest gdp per cap(qt)

# %%
plt.subplots()
plt.bar(qt['year'],qt['gdp_percap'])

plt.bar(uae['year'], uae['gdp_percap'])

plt.legend(['QATAR', 'UAE'])
